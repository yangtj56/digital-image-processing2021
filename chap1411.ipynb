# %% [markdown]
# #1.4.11 Image Transforms in OpenCV

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('mountain.jpeg',0) 
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

# %%
plt.figure(figsize=(18,12))

# %%
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
rows, cols = img.shape
crow, ccol = int(rows/2), int(cols/2)

# %%
img.shape
# Out:
# (160, 314)

# %%
# create a mask first, center square is 1, remaining all zeros
mask = np.zeros((rows,cols,2),np.uint8)
mask[crow-30:crow+30, ccol-30:ccol+30] = 1

# %%
# apply mask and inverse DFT
fshift = dft_shift*mask
f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ff30a14c4c23> in <module>
#       1 # apply mask and inverse DFT
# ----> 2 fshift = dft_shift*mask
#       3 f_ishift = np.fft.ifftshift(fshift)
#       4 img_back = cv2.idft(f_ishift)
#       5 img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
#
# NameError: name 'dft_shift' is not defined

# %%
plt.figure(figsize=(18,12))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-adcda346f566> in <module>
#       2 plt.subplot(121),plt.imshow(img, cmap = 'gray')
#       3 plt.title('Input Image'), plt.xticks([]), plt.yticks([])
# ----> 4 plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
#       5 plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
#       6 plt.show()
#
# NameError: name 'img_back' is not defined
