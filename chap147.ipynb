# %% [markdown]
# #Canny Edge Detection in OpenCV

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('lena.png',0)
edges = cv2.Canny(img,100,200)
edges1 = cv2.Canny(img,100,120)

# %%
plt.figure(figsize=(15,15))
plt.subplot(131),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(edges1,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
edges1 = cv2.Canny(img,100,120)
blur = cv2.GaussianBlur(img,(3,3),0)
edges2 = cv2.Canny(blur,100,120)
plt.figure(figsize=(15,15))
plt.subplot(121),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges1,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('lena.png',0)
blur = cv2.GaussianBlur(img,(3,3),0)
edges = cv2.Canny(img,100,200)

# %%
plt.figure(figsize=(12,12))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('lena.png')
img1 = cv2.pyrDown(img)

# %%
plt.figure(figsize=(15,15))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img1,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
img1.shape
# Out:
# (256, 256, 3)

# %%
img2 = cv2.pyrDown(img1)

# %%
img3 = cv2.pyrDown(img2)

# %%
img2.shape
# Out:
# (128, 128, 3)

# %%
img3.shape
# Out:
# (64, 64, 3)

# %%
img4 = cv2.pyrDown(img3)

# %%
img4.shape
# Out:
# (32, 32, 3)

# %%
plt.figure(figsize=(12,12))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img4,cmap = 'gray')
plt.title('pyrDown'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img41 = cv2.pyrUp(img4)

# %%
img42 = cv2.pyrUp(img41)

# %%
img43 = cv2.pyrUp(img42)

# %%
img44 = cv2.pyrUp(img43)

# %%
img44.shape
# Out:
# (512, 512, 3)

# %%
plt.figure(figsize=(12,12))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img44,cmap = 'gray')
plt.title('pyrDown'), plt.xticks([]), plt.yticks([])
plt.show()
